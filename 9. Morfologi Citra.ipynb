# %% [markdown]
# <a href="https://colab.research.google.com/github/viunadyapage/pengolahan-citra-digital/blob/main/9.%20Morfologi%20Citra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktek 9: 9. Morfologi Citra

# %%
# Import library yang diperlukan
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Langkah 1: Memuat citra dari URL atau file lokal
# Untuk praktikum ini, saya akan menggunakan URL drive gambar muka saya seperti praktik sebelumnya
url = 'https://drive.google.com/uc?export=download&id=1yQPIxMa06jJq5K_GBrn_n0gJzIdTyA7b'

# Mengunduh gambar dari URL
import urllib.request
urllib.request.urlretrieve(url, "nadya_tirta.png")

# Membaca citra menggunakan OpenCV
image = cv2.imread("nadya_tirta.png", cv2.IMREAD_GRAYSCALE)

# Langkah 2: Konversi citra ke biner menggunakan thresholding
_, binary_image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# Menampilkan citra biner
plt.figure(figsize=(8, 6))
plt.title("Citra Biner")
plt.imshow(binary_image, cmap='gray')
plt.axis('off')
plt.show()

# Langkah 3: Definisikan kernel untuk operasi morfologi
kernel = np.ones((5, 5), np.uint8)  # Kernel berukuran 5x5

# Langkah 4: Operasi Erosion
eroded_image = cv2.erode(binary_image, kernel, iterations=1)

# Menampilkan hasil operasi erosion
plt.figure(figsize=(8, 6))
plt.title("Hasil Erosion")
plt.imshow(eroded_image, cmap='gray')
plt.axis('off')
plt.show()

# Langkah 5: Operasi Dilation
dilated_image = cv2.dilate(binary_image, kernel, iterations=1)

# Menampilkan hasil operasi dilation
plt.figure(figsize=(8, 6))
plt.title("Hasil Dilation")
plt.imshow(dilated_image, cmap='gray')
plt.axis('off')
plt.show()

# Langkah 6: Operasi Opening
opened_image = cv2.morphologyEx(binary_image, cv2.MORPH_OPEN, kernel)

# Menampilkan hasil operasi opening
plt.figure(figsize=(8, 6))
plt.title("Hasil Opening")
plt.imshow(opened_image, cmap='gray')
plt.axis('off')
plt.show()

# Langkah 7: Operasi Closing
closed_image = cv2.morphologyEx(binary_image, cv2.MORPH_CLOSE, kernel)

# Menampilkan hasil operasi closing
plt.figure(figsize=(8, 6))
plt.title("Hasil Closing")
plt.imshow(closed_image, cmap='gray')
plt.axis('off')
plt.show()

print("Proses selesai! Anda telah melakukan operasi morfologi pada citra biner.")
# Out:
# Proses selesai! Anda telah melakukan operasi morfologi pada citra biner.
